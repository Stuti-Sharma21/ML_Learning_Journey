# %%
import numpy as np

def sigmoid(x):
  return 1/(1+np.exp(-x))

values=[-10,-5,0,5,10]

for v in values:
  print(v,"=>",sigmoid(v))
# Out:
# -10 => 4.5397868702434395e-05
# -5 => 0.0066928509242848554
# 0 => 0.5
# 5 => 0.9933071490757153
# 10 => 0.9999546021312976

# %%
import numpy as np

def sigmoid(x):
  return 1/(1+np.exp(-x))

m=2
b=-7

hours=[1,2,3,4,5,6]

for x in hours:

  z=m*x+b

  probability=sigmoid(z)

  print("hours = ",x,"probability = ",round(probability,3))#function to round probability upto 3 decimal places
# Out:
# hours =  1 probability =  0.007
# hours =  2 probability =  0.047
# hours =  3 probability =  0.269
# hours =  4 probability =  0.731
# hours =  5 probability =  0.953
# hours =  6 probability =  0.993

# %%
import numpy as np

def sigmoid(x):
  return 1/(1+np.exp(-x))

m=2
b=-7

hours=[1,2,3,4,5,6]

for x in hours:

  z=m*x+b

  probability=sigmoid(z)

  print("hours = ",x,"probability = ",round(probability,3))#function to round probability upto 3 decimal places

  if probability >= 0.5:
    print("pass")
  else:
    print("fail")
# Out:
# hours =  1 probability =  0.007
# fail
# hours =  2 probability =  0.047
# fail
# hours =  3 probability =  0.269
# fail
# hours =  4 probability =  0.731
# pass
# hours =  5 probability =  0.953
# pass
# hours =  6 probability =  0.993
# pass

# %%
#logistic regression with sklearn

# %%
import numpy as np

x=np.array([1,2,3,4,5,6]).reshape(-1,1)
y=np.array([0,0,0,1,1,1])

from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

model.fit(x,y)

newstudent=np.array([[6]])
prediction = model.predict(newstudent)
print(prediction)
probability=model.predict_proba(newstudent)
print(np.round(probability,3))
# Out:
# [1]
# [[0.057 0.943]]
